# %%
for beta in [0.2, 0.4, 0.6]:
    solution = odeint(sir_model, y0, t, args=(N, beta, gamma))
    S, I, R = solution.T
    plt.plot(t, I, label=f'β={beta}')

plt.xlabel('Time')
plt.ylabel('Infected')
plt.title('Effect of Infection Rate on Spread')
plt.legend()
plt.show()
